# %% [markdown]
# # Week 2 Day 3 Lab

# %% [markdown]
# ## Problem 1
# Import `numpy`, `math`, and `sympy`.

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\isaor\anaconda3\lib\site-packages (2.3.5)

# %%
import math
import numpy as np
import sympy as sy

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in c:\users\isaor\anaconda3\lib\site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\isaor\anaconda3\lib\site-packages (from sympy) (1.3.0)

# %% [markdown]
# The other libraries you had us download are below:

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\isaor\anaconda3\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\isaor\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\isaor\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\isaor\anaconda3\lib\site-packages (3.5)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\isaor\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\isaor\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\isaor\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\isaor\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\isaor\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\isaor\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# !pip install geopandas
# Out:
# Collecting geopandas
#   Downloading geopandas-1.1.4-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\isaor\anaconda3\lib\site-packages (from geopandas) (2.3.5)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.13.0-cp311-abi3-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\users\isaor\anaconda3\lib\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\isaor\anaconda3\lib\site-packages (from geopandas) (2.3.3)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\isaor\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\isaor\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\isaor\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\isaor\anaconda3\lib\site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\isaor\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.4-py3-none-any.whl (343 kB)
# Downloading pyogrio-0.13.0-cp311-abi3-win_amd64.whl (23.8 MB)
#    ---------------------------------------- 0.0/23.8 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/23.8 MB 10.6 MB/s eta 0:00:03
#    ----- ---------------------------------- 3.4/23.8 MB 8.7 MB/s eta 0:00:03
#    -------- ------------------------------- 5.2/23.8 MB 8.7 MB/s eta 0:00:03
#    ------------ --------------------------- 7.3/23.8 MB 9.0 MB/s eta 0:00:02
#    --------------- ------------------------ 9.2/23.8 MB 8.9 MB/s eta 0:00:02
#    ------------------ --------------------- 11.3/23.8 MB 9.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.4/23.8 MB 9.3 MB/s eta 0:00:02
#    -------------------------- ------------- 15.7/23.8 MB 9.5 MB/s eta 0:00:01
#    ----------------------------- ---------- 17.8/23.8 MB 9.4 MB/s eta 0:00:01
#    --------------------------------- ------ 19.7/23.8 MB 9.4 MB/s eta 0:00:01
#    ------------------------------------ --- 21.8/23.8 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------  23.6/23.8 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------------- 23.8/23.8 MB 8.8 MB/s  0:00:02
# Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.3 MB 5.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.1/6.3 MB 8.0 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 5.5/6.3 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 6.8 MB/s  0:00:00
# Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------------------------------------ --- 1.6/1.7 MB 9.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 8.2 MB/s  0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
#
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ---------------------------------------- 4/4 [geopandas]
#
# Successfully installed geopandas-1.1.4 pyogrio-0.13.0 pyproj-3.7.2 shapely-2.1.2

# %% [markdown]
# ## Problem 2
#
# 1. Write a recursive function `factorial()` that takes in a natural number `n` and computes $n!=n(n-1)(n-2)\cdots3\cdot2\cdot 1$.
# 2. Use `%timeit` to determine how fast your function calculates `factorial(150)`.
# 3. Use `%timeit` to calculate how fast `math.factorial()` calculates the same quantity.
# 4. Were there any differences between the two methods?

# %%
def factorial(n):
    if n <= 0:
        return "Not a positive integer"
    elif n == 1:
        return 1
    else:
        return n * factorial(n - 1)
factorial (150)
# Out:
# 

# %%
# %timeit factorial(150)
# Out:
# 26.9 μs ± 2.99 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit math.factorial(150)
# Out:
# 2.11 μs ± 190 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# My function took a decent amount longer to compute.

# %% [markdown]
# ## Problem 3
# Recall for a quadratic equation of the form
# $$ax^2 + bx + c = 0
# $$
#
# The solutions are given by the <i>quadratic formula</i>:
#
# $$
# x=\frac{-b\pm\sqrt{b^2-4ac}}{2a}
# $$
#
# 1. Write a function `quadratic()` that calculates the two roots given by the quadratic formula only if they are real.
# 2. Use `%timeit` to determine how fast your function calculates the roots for $437x^2 - 915x + 478 = 0$.
# 3. Use `%timeit` to calculate how fast `sp.solve()` calculates the same quantities.
# 4. Were there any differences between the two methods?

# %%
def quadratic(a, b, c):
    discriminant = b**2 - 4*a*c
    
    if discriminant < 0:
        return "No real roots"
    
    pos = (-b + math.sqrt(discriminant)) / (2*a)
    neg = (-b - math.sqrt(discriminant)) / (2*a)
    
    return pos, neg

quadratic(437, -915, 478)
# Out:
# (1.0938215102974829, 1.0)

# %%
# %timeit quadratic(437, -915, 478)
# Out:
# 552 ns ± 29.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
x = sy.symbols('x')
print(sy.solve(437*x**2 - 915*x + 478))
# %timeit sy.solve(
# Out:
# [1, 478/437]
# 2.45 ms ± 172 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# Again, my function was signifacntly longer to process. Using imorts seems to greatly decrease the power and time necessary for a computation.

# %% [markdown]
# ## Problem 4
#
# For each of the following functions, use `sympy` calculate the first derivative, the second derivative, and the integral (all with respect to $x$):
#
# 1. $f(x)=x$
# 2. $f(x)=6x^{-1/2}$
# 3. $f(x)=\pi\sqrt{x}+x^5+7$
# 4. $f(x)=x(2x-5)(3+\tan(x))$

# %% [markdown]
# For problem 4, I replaces the tangent for sine since the integration doesn't work if you have tangent.

# %%
f = x
print (sy.diff(f,x))
print (sy.diff(sy.diff(f,x)))
print (sy.integrate(f,x))
# Out:
# 1
# 0
# x**2/2

# %%
g = 6*x**-1/2
print (sy.diff(g,x))
print (sy.diff(sy.diff(g,x)))
print (sy.integrate(g,x))
# Out:
# -3/x**2
# 6/x**3
# 3*log(x)

# %%
h = (math.pi) * x**1/2 + x**5 + 7
print (sy.diff(h,x))
print (sy.diff(sy.diff(h,x)))
print (sy.integrate(h,x))
# Out:
# 5*x**4 + 1.5707963267949
# 20*x**3
# 0.166666666666667*x**6 + 0.785398163397448*x**2 + 7.0*x

# %%
x = sy.Symbol('x')
w = x * (2*x - 5) * (3 + sy.sin(x))
print(sy.diff(w, x))
print (sy.diff(sy.diff(w,x)))
print (sy.integrate(w,x))
# Out:
# x*(2*x - 5)*cos(x) + 2*x*(sin(x) + 3) + (2*x - 5)*(sin(x) + 3)
# -x*(2*x - 5)*sin(x) + 4*x*cos(x) + 2*(2*x - 5)*cos(x) + 4*sin(x) + 12
# 2*x**3 - 2*x**2*cos(x) - 15*x**2/2 + 4*x*sin(x) + 5*x*cos(x) - 5*sin(x) + 4*cos(x)

# %% [markdown]
# ## Problem 5
#
# From yesterday, we calculated <i>numerically</i> what the derivative of $\sin(x)$ is.
# 1. Using sympy, calculate derivative at 0.
# 2. Using sympy, evaluate the limit definition of the derivative for $f(x)=\sin(x)$:
# $$f'(x)=\lim_{h\to0}\frac{f(x+h)-f(x)}{h}
# $$

# %%
x = sy.Symbol('x')
f = sy.sin(x)
der = sy.diff(f, x)
print(der)
print(der.subs(x, 0))
# Out:
# cos(x)
# 1

# %% [markdown]
# Similar to a lab from last week, I had help from the internet. I feel like I have trouble rercognizing what to use and where.

# %%
x = sy.Symbol('x')
h = sy.Symbol('h')
print(sy.limit((sy.sin(x+h)-sy.sin(x))/h, h, 0))
# Out:
# cos(x)
